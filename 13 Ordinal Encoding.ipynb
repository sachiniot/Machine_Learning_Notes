# %%
import pandas as pd
from sklearn.preprocessing import OrdinalEncoder

# %%
df=pd.read_csv("C:\\Users\\mukes\\OneDrive\\Documents\\ML\\ipl data set.csv")
df.head()
# Out:
#    match_id batting_team bowling_team                   venue  \
# 0         1          CSK          RCB    Rajiv Gandhi Stadium
# 1         2          SRH           DC    Rajiv Gandhi Stadium
# 2         3          SRH         PBKS    Rajiv Gandhi Stadium
# 3         4         PBKS           RR        Wankhede Stadium
# 4         5         PBKS           GT  Sawai Mansingh Stadium
#
#          pitch_type pitch_condition  current_score  overs_completed  \
# 0          Balanced             Dry            133               12
# 1  Batting Friendly             Dry             76               16
# 2          Balanced           Green            126               13
# 3  Batting Friendly           Dusty             65               13
# 4  Bowling Friendly           Green             32                5
#
#    wickets_out  runs_last_5_overs  overs_remaining  wickets_remaining  \
# 0            5                 68                8                  5
# ...

# %%
encoder1=OrdinalEncoder()
df['pitch_condition']=encoder1.fit_transform(df[['pitch_condition']])
df.head()
'''   

IN OneHotEncoding we input one column and output is multiple columns of that one column so we have to create a new dataframe for those multiple columns and deleting the original columns from dataset
but in ordinal encoding input of one column gives output of only one columns so no need to create a new dataframe just replace it with original column.

'''
# Out:
#    match_id batting_team bowling_team                   venue  \
# 0         1          CSK          RCB    Rajiv Gandhi Stadium
# 1         2          SRH           DC    Rajiv Gandhi Stadium
# 2         3          SRH         PBKS    Rajiv Gandhi Stadium
# 3         4         PBKS           RR        Wankhede Stadium
# 4         5         PBKS           GT  Sawai Mansingh Stadium
#
#          pitch_type  pitch_condition  current_score  overs_completed  \
# 0          Balanced              0.0            133               12
# 1  Batting Friendly              0.0             76               16
# 2          Balanced              3.0            126               13
# 3  Batting Friendly              1.0             65               13
# 4  Bowling Friendly              3.0             32                5
#
#    wickets_out  runs_last_5_overs  overs_remaining  wickets_remaining  \
# 0            5                 68                8                  5
# ...
